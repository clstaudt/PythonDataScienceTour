# %%
ls data
# Out:
# Departements.csv            Liste_musees_de_France.xls

# %%
import pandas

# %%
from unidecode import unidecode

# %%
# !head data/Departements.csv
# Out:
# La Réunion;4;25;24;842.767;852.657

# %%
departements = pandas.read_csv("data/Departements.csv", sep=";")

# %%
departements.head()
# Out:
#         Nom du département  Nombre d'arrondissements  Nombre de cantons  \
# 0                      Ain                         4               23.0
# 1                    Aisne                         5               21.0
# 2                   Allier                         3               19.0
# 3  Alpes-de-Haute-Provence                         4               15.0
# 4             Hautes-Alpes                         2               15.0
#
#    Nombre de communes Population municipale Population totale
# 0                 410               626.127           643.309
# 1                 805               539.783           554.040
# 2                 318               343.062           353.262
# 3                 199               161.588           166.298
# 4                 168               139.883           145.213

# %%
departements = departements[["Nom du département", "Population totale"]]

# %%
museums = pandas.read_excel("data/Liste_musees_de_France.xls")

# %%
museums.head()
# Out:
#    NOMREG    NOMDEP DATEAPPELLATION FERME      ANNREOUV ANNEXE  \
# 0  ALSACE  BAS-RHIN      01/02/2003   NON           NaN    NaN
# 1  ALSACE  BAS-RHIN      01/02/2003   NON           NaN    NaN
# 2  ALSACE  BAS-RHIN      01/02/2003   OUI  29 juin 2013    NaN
# 3  ALSACE  BAS-RHIN      01/02/2003   NON           NaN    NaN
# 4  ALSACE  BAS-RHIN      01/02/2003   NON           NaN    NaN
#
#                               NOM DU MUSEE  \
# 0                  Musée de la Folie Marco
# 1                      Musée de la Poterie
# 2  Musée de Bouxwiller et du Pays de Hanau
# 3                           Musée Alsacien
# 4                         Musée Historique
#
#                                    ADR     CP           VILLE  \
# 0                30, Rue du Dr Sultzer  67140            BARR
# 1                 2, rue de Kuhlendorf  67660      BETSCHDORF
# 2  2, Place du Château\nHalle aux Blés  67330      BOUXWILLER
# 3              1, place Joseph Thierry  67500        HAGUENAU
# 4  9, Rue du Maréchal Foch\nB.P. 40261  67504  HAGUENAU Cedex
#
#                                               SITWEB  \
# 0                                        www.barr.fr
# 1  www.betschdorf.fr/tourisme/visiter_betschdrof/...
# 2                  www.musee-pays-hanau.webmuseo.com
# 3      www.ville-haguenau.fr/pages/culture/musee.htm
# 4  www.ville-haguenau.fr/pages/culture/musee.htm ...
#
#                                   FERMETURE ANNUELLE  \
# 0                                   Novembre à avril
# 1                                Novembre à mi-avril
# 2                                                NaN
# 3  1er janvier, dimanche de Pâques, 1er mai, 1er ...
# 4  1er janvier, dimanche de Pâques, 1er mai, 1er ...
#
#                                    PERIODE OUVERTURE JOURS NOCTURNES
# 0  Ouvert de mai à septembre du mercredi au lundi...             NaN
# 1  Ouvert du mardi au samedi de 10h à 12h et de 1...             NaN
# 2  Fermé. Ouvert uniquement sur réservation pour ...             NaN
# 3  Ouvert du lundi au vendredi de 9h à 12h et de ...             NaN
# 4  Ouvert lundi de 14h à 18h, mercredi au vendred...             NaN

# %%
museums["NOMDEP"] = museums["NOMDEP"].apply(lambda s: s.replace("-", " "))

# %%
museum_count = museums.groupby("NOMDEP").size()

# %%
museum_count.head(20)
# Out:
# NOMDEP
# AIN                        14
# AISNE                      15
# ALLIER                      9
# ALPES DE HAUTE PROVENCE     9
# ALPES MARITIMES            33
# ARDECHE                     8
# ARDENNES                    8
# ARIEGE                      6
# AUBE                       11
# AUDE                        9
# AVEYRON                    11
# BAS RHIN                   24
# BOUCHES DU RHONE           44
# CALVADOS                   23
# CANTAL                      5
# CHARENTE                    6
# CHARENTE MARITIME          19
# CHER                        9
# CORREZE                     5
# CORSE DU SUD                5
# dtype: int64

# %%
departements["Nom du département"] = departements["Nom du département"].apply(lambda s: s.upper())
departements["Nom du département"] = departements["Nom du département"].apply(lambda s: s.replace("-", " "))

# %%
departements.head(20)
# Out:
#          Nom du département Population totale
# 0                       AIN           643.309
# 1                     AISNE           554.040
# 2                    ALLIER           353.262
# 3   ALPES DE HAUTE PROVENCE           166.298
# 4              HAUTES ALPES           145.213
# 5           ALPES MARITIMES         1.098.785
# 6                   ARDÈCHE           332.051
# 7                  ARDENNES           287.775
# 8                    ARIÈGE           158.076
# 9                      AUBE           316.098
# 10                     AUDE           375.065
# 11                  AVEYRON           289.901
# 12         BOUCHES DU RHÔNE         2.035.475
# 13                 CALVADOS           708.407
# 14                   CANTAL           152.400
# 15                 CHARENTE           366.787
# 16        CHARENTE MARITIME           656.046
# 17                     CHER           318.590
# 18                  CORRÈZE           249.684
# 19             CORSE DU SUD           154.100

# %%
departements.index = departements["Nom du département"]
departements.drop(["Nom du département"], axis=1, inplace=True)

# %%
departements.head(20)
# Out:
#                         Population totale
# Nom du département
# AIN                               643.309
# AISNE                             554.040
# ALLIER                            353.262
# ALPES DE HAUTE PROVENCE           166.298
# HAUTES ALPES                      145.213
# ALPES MARITIMES                 1.098.785
# ARDÈCHE                           332.051
# ARDENNES                          287.775
# ARIÈGE                            158.076
# AUBE                              316.098
# AUDE                              375.065
# AVEYRON                           289.901
# BOUCHES DU RHÔNE                2.035.475
# CALVADOS                          708.407
# CANTAL                            152.400
# CHARENTE                          366.787
# CHARENTE MARITIME                 656.046
# CHER                              318.590
# CORRÈZE                           249.684
# CORSE DU SUD                      154.100

# %%
joined = departements.join(pandas.DataFrame(museum_count, index=museum_count.index, columns=["number of museums"]))

# %%
joined.head()
# Out:
#                         Population totale  number of museums
# Nom du département
# AIN                               643.309               14.0
# AISNE                             554.040               15.0
# ALLIER                            353.262                9.0
# ALPES DE HAUTE PROVENCE           166.298                9.0
# HAUTES ALPES                      145.213                2.0

# %%
joined["Population totale"] = joined["Population totale"].apply(lambda s: pandas.to_numeric(s, errors="drop"))

# %%
joined.corr()
# Out:
#                    Population totale  number of museums
# Population totale           1.000000           0.625184
# number of museums           0.625184           1.000000
